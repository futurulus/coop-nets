# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
Cleans up the data from the chinese message corpus
1 - Removes messages greater than 4 standard deviations away from the mean
2 - Removes spam games
Author: Andrew
"""
import os
import pandas as pd
import numpy as np
import re
# import jieba
import nltk.tokenize

# === Constants ===
IN_DIR = 'data_input_raw'
OUT_DIR = 'data_input_cleaned'
INPUT_FILE = 'colorReferenceMessageChinese.csv'
MESSAGE_COLUMN = 'contents'
SEPARATOR = ','
NUM_COLUMNS = 5 # num columns in the csv files

# === Parameters ===
MAX_STD = 4 # for length
MAX_DUPLICATES = 25 # for spam. this number is the maximum number of the same reoccuring message in a game

def main():
    """
    Performs preprocessing (cleanup) on the chinese message data
    """
    raw_df = open_raw_df()
    print 'Columns:', raw_df.columns
    raw_num_rows = raw_df.shape[0]
    print 'Original num datapoints:', raw_num_rows

    # filter out the long messages and get information
    print '\nFiltering out messages with word counts exceeding {} standard deviations.'.format(MAX_STD)
    filtered_df, deleted_len_df, mean, std = filter_long_messages(raw_df, MAX_STD)
    fil_len_num_rows = filtered_df.shape[0]
    # print summary results for filtered by length
    print 'Mean: {}, std: {}'.format(mean, std)
    print 'Num messages removed by excessive word counts:', raw_num_rows - fil_len_num_rows
    print 'Num datapoints remaining:', fil_len_num_rows

    # filter out the spam games
    print '\nFiltering out messages with spams containing more than {} duplicates.'.format(MAX_DUPLICATES)
    filtered_df, deleted_spam_df = filter_spam_games(filtered_df, MAX_DUPLICATES)
    num_spam_games = len(deleted_spam_df.groupby('gameid'))
    fil_spam_num_rows = filtered_df.shape[0]
    # print summary results for filtered by spam
    print 'Num spam games:', num_spam_games
    print 'Num messages removed by spam:', fil_len_num_rows - fil_spam_num_rows
    print 'Num datapoints remaining:', fil_spam_num_rows
    print '\nTotal removed:', raw_num_rows - fil_spam_num_rows

    # filter out the misunderstood games
    print '\nFiltering out games from players reporting confusion of the game.'
    filtered_df, deleted_confused_df = filter_confused_players(filtered_df)
    fil_confused_num_rows = filtered_df.shape[0]
    # print summary results for filtered by spam
    print 'Num messages removed from confused:', fil_spam_num_rows - fil_confused_num_rows
    print 'Num datapoints remaining:', fil_confused_num_rows
    print '\nTotal removed:', raw_num_rows - fil_confused_num_rows

    # Write filtered to file
    print '\nWriting to file'
    filtered_out_name = os.path.join(OUT_DIR, INPUT_FILE[:-4] + '_filtered.csv')
    print 'Writing filtered to', filtered_out_name
    filtered_df.to_csv(filtered_out_name, encoding='utf-8', index=False)

    # Write what got removed, to check what got removed makes sense
    # long
    del_len_out_name = os.path.join(OUT_DIR, 'filtered_deleted_long_lengths.csv')
    print 'Writing removed messages from excessive word counts to', del_len_out_name
    deleted_len_df.to_csv(del_len_out_name, encoding='utf-8', index=False)
    # spam
    del_spam_out_name = os.path.join(OUT_DIR, 'filtered_deleted_spam.csv')
    print 'Writing removed messages from spam games to', del_spam_out_name
    deleted_spam_df.to_csv(del_spam_out_name, encoding='utf-8', index=False)
    # confused
    del_confused_out_name = os.path.join(OUT_DIR,'filtered_deleted_confused.csv')
    print 'Writing removed messages from confused players to', del_confused_out_name
    deleted_confused_df.to_csv(del_confused_out_name, encoding='utf-8', index=False)

    print 'Done.'

def open_raw_df():
    # remove extra commas from the messages
    stripped_file_name = remove_extra_separators(os.path.join(IN_DIR, INPUT_FILE))
    opened_stripped_f = open(stripped_file_name, 'r')

    # read csv into a pandas df
    return pd.read_csv(opened_stripped_f, sep=SEPARATOR)

def remove_extra_separators(input_file):
    """
    This function is kind of pre-preprocessing. The chinese messages corpus is only supposed to have 5 columns per 
    datapoint. Any extra separators that occur in the dialog needs to be removed for the file to be read correctly. 
    The number of columns is set with the constant NUM_COLUMNS.

    :param input_file: the raw converted csv file from jsonToCSV.py
    :returns: name of the file stripped of extra commas
    """
    f = open(input_file, 'r')
    out_f = open(OUT_DIR + 'raw_stripped_extra_commas.csv', 'w')
    for line in f:
        split = line.split(SEPARATOR)
        if len(split) > NUM_COLUMNS:
            # gameid, epochTime, roundNum, role, message,could,have,extra,separators
            num_seps = NUM_COLUMNS - 1
            # rejoin the previous columns with the original separator, then fill in spaces on the extraneous seps
            new_line = SEPARATOR.join(split[slice(num_seps)]) + ' '.join(split[slice(num_seps, len(split))])
        else:
            new_line = SEPARATOR.join(split)
        out_f.write(new_line)

    f.close()
    return out_f.name

def filter_long_messages(raw_df, std=4):
    """
    Removes messages with lengths GREATER than the number of standard deviations given.

    :param df: pandas dataframe
    :param std: number of standard deviations

    :returns: the filtered df, the rows that were removed, the mean, the std
    """
    # We have to use msg.decode('utf-8') so that chinese characters are properly evaluated as 1 character.
    # Technically this means that messages with english will be more likely to be thrown out, as spaces and letters
    # are single characters. This may or may not be an issue.
    raw_df['word_count'] = raw_df[MESSAGE_COLUMN].astype(str).apply(mixed_lang_word_count)
    length_mean = raw_df['word_count'].mean()
    length_std = raw_df['word_count'].std()
    raw_df['z_scores'] = (raw_df['word_count'] - length_mean) / length_std
    # keep based on z_score (the num of standard deviations)
    filtered_length_df = raw_df[raw_df['z_scores'] <= std]
    deleted_length_df = raw_df[raw_df['z_scores'] > std]

    # remove the columns we added for calculating and filtering
    filtered_length_df = filtered_length_df.drop('word_count', axis=1)
    filtered_length_df = filtered_length_df.drop('z_scores', axis=1)

    return filtered_length_df, deleted_length_df, length_mean, length_std

def mixed_lang_word_count(string):
    """
    Returns the word count of a string containing English and Chinese words. The string is split into English and Chinese,
    then returns the sum of the word counts from both substrings based on NLTK and Jieba.
    E.g. '你好 Andrew' returns 2, as '你好' is one word and 'Andrew' is another.

    :param string: a string containing english and chinese
    :returns: the word count
    """
    english_only = re.sub(r'\W+', '', string)
    num_eng_words = len(nltk.word_tokenize(english_only))

    non_english_only = re.sub(r'\w+', '', string)
    num_non_eng_words = len(list(jieba.tokenize(non_english_only.decode('utf-8'))))

    return num_eng_words + num_non_eng_words


def filter_spam_games(df, threshold):
    """
    Filter out games (based on gameid) with duplicated messages greater than or equal to the threshold value. 
    A message is considered to be a duplicate if it appears more than once.
    E.g. if the threshold is 5, games with 5 or more duplicated messages

    :param df: the message df to filter
    :param threshold: the max number (exclusive) of duplicate messages. The max duplicated message is compared to the 
        threshold, ie 3 occurences of 'aaa' and 2 occurences of 'bbb' has a max duplicated value of 3, thus 3 is used.
    :returns: tuple first containing the filtered dataframe, and second the rows that were deleted
    """
    # filter out bad games. group by id, then group by the contents, then get the max size of the grouped contents
    filtered_spam_df = df.groupby('gameid').filter(lambda g: g.groupby('contents').size().max() < threshold)
    deleted_spam_df = df.groupby('gameid').filter(lambda g: g.groupby('contents').size().max() >= threshold)

    return filtered_spam_df, deleted_spam_df

def filter_confused_players(message_df):
    """
    docstring here
    :param message_df: pandas dataframe containing the messages
    :param hit_df: pandas dataframe containing the hits
    """
    hit_df = hit_results_to_df()
    # combine together the Answer1-4 columns, because for some reason data is everywhere in there
    hit_df['feedback'] = hit_df['Answer 1'].map(str) + hit_df['Answer 2'].map(str) + hit_df['Answer 3'].map(str) \
        + hit_df['Answer 4'].map(str)

    hit_df['understood'] = hit_df['feedback'].apply(lambda x: '"understood":"yes"' in x)
    hit_df['gameid'] = hit_df['feedback'].apply(find_game_id)
    # use only the gameid and understood columns
    hit_df = hit_df[['gameid', 'understood']]
    hit_df = hit_df.dropna(subset=['gameid'])

    # associate the response by gameid
    message_df = pd.merge(message_df, hit_df[['gameid', 'understood']], how='left', on='gameid')
    # fill non-respondents with True to only take out players if they specifically said they didn't understand the game
    message_df['understood'] = message_df['understood'].fillna(True)

    filtered_df = message_df[message_df['understood'] == True].drop(['understood'], axis=1)
    deleted_df = message_df[message_df['understood'] == False]

    return filtered_df, deleted_df

def hit_results_to_df():
    """
    Combines the .csv files in the /hit_results/ directory into a dataframe.
    :returns: the combined dataframe
    """
    df = pd.DataFrame() # init an empty dataframe
    for filename in os.listdir(os.path.join('hit_results')):
        if filename.startswith('HITResults') and filename.endswith('.csv'):
            sub_df = pd.read_csv(os.path.join('hit_results', filename))
            if len(sub_df.columns) == 13 and 'Answer 4' in sub_df.columns:
                df = df.append(sub_df, ignore_index=True)
    return df

def find_game_id(string):
    match = re.search(r'"+gameID"+:"+([\w-]+)"+', string)
    if match is not None:
        return match.group(1)
    else:
        return np.nan

# %%
message_df = open_raw_df()
message_df
# Out:
#                                          gameid      epochTime  roundNum  \
# 0     7645-31884455-9ae0-4726-a830-00d8014ac468  1501009770723         1
# 1     7645-31884455-9ae0-4726-a830-00d8014ac468  1501009780640         1
# 2     7645-31884455-9ae0-4726-a830-00d8014ac468  1501009792580         1
# 3     7645-31884455-9ae0-4726-a830-00d8014ac468  1501009803540         1
# 4     7645-31884455-9ae0-4726-a830-00d8014ac468  1501009828080         2
# 5     7645-31884455-9ae0-4726-a830-00d8014ac468  1501009849356         3
# 6     7645-31884455-9ae0-4726-a830-00d8014ac468  1501009871308         4
# 7     7645-31884455-9ae0-4726-a830-00d8014ac468  1501009889576         5
# 8     7645-31884455-9ae0-4726-a830-00d8014ac468  1501009910004         6
# 9     7645-31884455-9ae0-4726-a830-00d8014ac468  1501009933371         7
# 10    7645-31884455-9ae0-4726-a830-00d8014ac468  1501009949791         8
# 11    7645-31884455-9ae0-4726-a830-00d8014ac468  1501009974025         9
# 12    7645-31884455-9ae0-4726-a830-00d8014ac468  1501009991587        10
# 13    7645-31884455-9ae0-4726-a830-00d8014ac468  1501010015824        11
# 14    1531-0519ed42-819e-47c9-aec3-73f1bfa8b697  1501032293921         0
# 15    1531-0519ed42-819e-47c9-aec3-73f1bfa8b697  1501032306600         0
# 16    1531-0519ed42-819e-47c9-aec3-73f1bfa8b697  1501032315179         0
# 17    1531-0519ed42-819e-47c9-aec3-73f1bfa8b697  1501032324477         0
# 18    4052-994445f3-3f93-483b-bf8b-b2b3fcee8e28  1501033341734         0
# 19    4052-994445f3-3f93-483b-bf8b-b2b3fcee8e28  1501033359914         0
# 20    4052-994445f3-3f93-483b-bf8b-b2b3fcee8e28  1501033392693         0
# 21    4052-994445f3-3f93-483b-bf8b-b2b3fcee8e28  1501033482990         0
# 22    3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096118786         1
# 23    3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096130075         1
# 24    3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096152265         2
# 25    3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096181129         3
# 26    3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096198124         4
# 27    3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096214088         5
# 28    3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096236253         6
# 29    3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096256219         7
# ...                                         ...            ...       ...
# 6504  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424621076        22
# 6505  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424628073        23
# 6506  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424635664        24
# 6507  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424718291        25
# 6508  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424733955        26
# 6509  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424741020        27
# 6510  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424747533        28
# 6511  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424754314        29
# 6512  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424762806        30
# 6513  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424770017        31
# 6514  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424777150        32
# 6515  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424787118        33
# 6516  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424807586        34
# 6517  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424817994        35
# 6518  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424963764        36
# 6519  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424971295        37
# 6520  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424979630        38
# 6521  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424993981        39
# 6522  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425025545        40
# 6523  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425083334        41
# 6524  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425097110        42
# 6525  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425122576        43
# 6526  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425132328        44
# 6527  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425244273        45
# 6528  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425251659        46
# 6529  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425266458        47
# 6530  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425277699        48
# 6531  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425297972        49
# 6532  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425326379        50
# 6533  3084-c6f2ba46-4b6e-41df-b3fd-133e3c75096f  1505487924118         0
#
#      sender       contents
# 0       倾听者             hi
# 1       演说者            接近地
# 2       演说者            的颜色
# 3       倾听者            灰色？
# 4       倾听者              ？
# 5       倾听者              ？
# 6       演说者           树的颜色
# 7       演说者             冷色
# 8       演说者           草的颜色
# 9       演说者             肉桂
# 10      倾听者              ？
# 11      倾听者              ？
# 12      倾听者              ？
# 13      倾听者              ？
# 14      演说者          Black
# 15      演说者          White
# 16      演说者  Ok good color
# 17      演说者           Reji
# 18      演说者              红
# 19      演说者              红
# 20      演说者              紅
# 21      演说者            RED
# 22      倾听者              ？
# 23      演说者          深色的血液
# 24      演说者             深海
# 25      演说者          女士 高雅
# 26      演说者              龙
# 27      演说者             土地
# 28      演说者             最深
# 29      演说者             艳丽
# ...     ...            ...
# 6504    倾听者        嘿最近怎么样。
# 6505    倾听者        嘿最近怎么样。
# 6506    倾听者        嘿最近怎么样。
# 6507    倾听者        嘿最近怎么样。
# 6508    倾听者        嘿最近怎么样。
# 6509    倾听者        嘿最近怎么样。
# 6510    倾听者        嘿最近怎么样。
# 6511    倾听者        嘿最近怎么样。
# 6512    倾听者        嘿最近怎么样。
# 6513    倾听者        嘿最近怎么样。
# 6514    倾听者        嘿最近怎么样。
# 6515    倾听者        嘿最近怎么样。
# 6516    倾听者        嘿最近怎么样。
# 6517    倾听者        嘿最近怎么样。
# 6518    倾听者        嘿最近怎么样。
# 6519    倾听者        嘿最近怎么样。
# 6520    倾听者        嘿最近怎么样。
# 6521    倾听者        嘿最近怎么样。
# 6522    倾听者        嘿最近怎么样。
# 6523    倾听者        嘿最近怎么样。
# 6524    倾听者        嘿最近怎么样。
# 6525    倾听者        嘿最近怎么样。
# 6526    倾听者        嘿最近怎么样。
# 6527    倾听者        嘿最近怎么样。
# 6528    倾听者        嘿最近怎么样。
# 6529    倾听者        嘿最近怎么样。
# 6530    倾听者        嘿最近怎么样。
# 6531    倾听者        嘿最近怎么样。
# 6532    倾听者        嘿最近怎么样。
# 6533    演说者            没人啊
#
# [6534 rows x 5 columns]

# %%
hit_df = hit_results_to_df()
# combine together the Answer1-4 columns, because for some reason data is everywhere in there
hit_df['feedback'] = hit_df['Answer 1'].map(str) + hit_df['Answer 2'].map(str) + hit_df['Answer 3'].map(str) \
    + hit_df['Answer 4'].map(str)

hit_df['understood'] = hit_df['feedback'].apply(lambda x: '"understood":"yes"' in x)
hit_df['gameid'] = hit_df['feedback'].apply(find_game_id)
# use only the gameid and understood columns
hit_df = hit_df[['gameid', 'understood']]
hit_df = hit_df.dropna(subset=['gameid'])
hit_df
# Out:
#                                         gameid  understood
# 0    3705-957c84bc-b173-4849-994e-f8334f0a068c        True
# 1    3705-957c84bc-b173-4849-994e-f8334f0a068c        True
# 2    6241-d488a9b6-9ab8-4591-b4f3-74104bfe0bff        True
# 3    8165-20800829-2a8a-4f35-841a-df601b2b69e5        True
# 4    8165-20800829-2a8a-4f35-841a-df601b2b69e5        True
# 5    2118-15d75aa3-3c3c-47d9-bf7b-50f0b609b9a5        True
# 6    5481-2a79b18d-c282-4cd0-a614-948b739eda3f        True
# 7    9491-0cb3a3f2-ad5c-42db-9cf6-703d17442878        True
# 8    2807-253d3ab7-b1a1-4a7d-ae7d-7f56c9bf304c        True
# 9    2292-90a01583-25d1-4d87-a41b-9f772c314d61        True
# 10   7024-9f33f165-8d4a-44db-8b60-8236445b9073        True
# 11   7222-e243dab1-ed91-439d-a2c2-d5db38ba46c7        True
# 12   4871-cf777231-c870-4b4c-a1aa-4a65f893dd95        True
# 13   9485-a972797e-4d32-4a76-94ca-5ed073e2226f        True
# 14   4060-c2f68154-e41a-4a3f-820e-e0dffe8ae021        True
# 15   0160-1ccf74c5-ea9e-4f4a-a8ca-2d23cd54e72b        True
# 16   5261-7707a0bf-7d54-4c71-bfd6-8b7ce36253a6        True
# 17   1347-63fbe404-fa6f-4620-8e03-bce81cde143f        True
# 18   9663-c4af24b7-a2b0-4ccd-97ce-8b6bf3e18b0f        True
# 19   9663-c4af24b7-a2b0-4ccd-97ce-8b6bf3e18b0f        True
# 20   9916-25fcf3b6-06a6-43ea-b5ac-f345a5eab39e        True
# 21   3264-a6cb1ac5-8861-4de5-a08c-103ecd70a22a        True
# 22   7961-742222fd-fc56-4b16-bc42-f0871d7e1811        True
# 23   7961-742222fd-fc56-4b16-bc42-f0871d7e1811        True
# 24   3116-d0bcd0d4-f5ca-4e4c-84a9-1e8abe84811e        True
# 25   3116-d0bcd0d4-f5ca-4e4c-84a9-1e8abe84811e        True
# 26   9948-111db5e5-f5fb-479c-a10f-b993546f574c       False
# 27   8373-5f19014c-cc09-41e9-8345-b22653853f98        True
# 28   8373-5f19014c-cc09-41e9-8345-b22653853f98        True
# 29   0471-8c8ebdfa-4ed1-4017-81fc-146a6b9cac7c        True
# ..                                         ...         ...
# 157  5465-9799631c-c1a7-4b17-8944-307f2bf89df2        True
# 158  6480-edf2ce8f-66fb-4115-9e44-bc280541ad81        True
# 159  9068-8040e841-54a3-451f-ac7c-ca6f427f4be9        True
# 160  0179-3907c1f5-d5d8-40e2-a432-1f3209784bb5        True
# 161  7487-30dca896-cdbb-4206-9da0-7d50118429fc        True
# 162  9968-e4602c3d-3038-4fb1-a903-9d027de07607        True
# 163  9968-e4602c3d-3038-4fb1-a903-9d027de07607       False
# 164  5396-f99dbd1f-6a7f-409f-8bd9-3bb073691cde        True
# 165  2224-22d919e2-e53a-4e0e-a820-391c84c00ace        True
# 166  8049-07b2dbdd-ce5d-4089-9900-786ece5d773e        True
# 167  7226-ccc3b8d4-37a4-4334-9095-74260418e8c1        True
# 168  2095-70f49730-5b45-4547-906f-c9b8ec6fdef5        True
# 169  1517-49a63cdf-2f16-4329-86bf-fb25c0f793f0        True
# 170  1880-d2ba73d9-8b96-44a7-9277-459ac5fbb7d1        True
# 171  4304-0a6471c9-b6e3-4df3-9257-13c0310185d6        True
# 172  8117-d2d03ddc-79b6-48bd-919b-6ebae4df1f8c        True
# 173  2262-8c760668-2da6-48cf-aed1-b65296b8ad17        True
# 174  8146-390e8c1f-f8e2-4a34-bd93-a394f87746a0        True
# 175  2840-54e4f53c-08b4-4997-8d4c-199971ca2f9f        True
# 176  4279-0a696d98-4034-4852-8058-d764d6aed7ae        True
# 177  4905-268cfc40-a27c-4ea4-8efc-25081be7de0e        True
# 178  9822-185db7df-8945-4c9e-892f-a06fa847c7ab        True
# 179  4733-58f62658-c52c-4fff-b103-b98a7c7697c9        True
# 180  9774-2b854280-85e1-4a24-a2eb-86f37d1dbda4        True
# 181  9774-2b854280-85e1-4a24-a2eb-86f37d1dbda4        True
# 182  1085-cc293401-dc16-4f5c-bf98-4e743960c628        True
# 183  1062-5250acff-a1c6-499b-af16-212bc1953e10        True
# 184  9367-6b5c55e8-6678-425f-8d4b-5fd155c7406d        True
# 185  9367-6b5c55e8-6678-425f-8d4b-5fd155c7406d        True
# 186  1177-a8f612ff-21c1-47e4-90f9-3c9dadcefaf1        True
#
# [187 rows x 2 columns]

# %%
hit_df = hit_df[~hit_df.understood]
hit_df
# Out:
#                                         gameid  understood
# 26   9948-111db5e5-f5fb-479c-a10f-b993546f574c       False
# 111  8144-3eb0a9fc-4b09-40b1-af8f-96cdc27e6c9b       False
# 163  9968-e4602c3d-3038-4fb1-a903-9d027de07607       False

# %%
# associate the response by gameid
new_df = message_df[~message_df['gameid'].isin(hit_df['gameid'])].reset_index()
new_df
# Out:
#       index                                     gameid      epochTime  \
# 0         0  7645-31884455-9ae0-4726-a830-00d8014ac468  1501009770723
# 1         1  7645-31884455-9ae0-4726-a830-00d8014ac468  1501009780640
# 2         2  7645-31884455-9ae0-4726-a830-00d8014ac468  1501009792580
# 3         3  7645-31884455-9ae0-4726-a830-00d8014ac468  1501009803540
# 4         4  7645-31884455-9ae0-4726-a830-00d8014ac468  1501009828080
# 5         5  7645-31884455-9ae0-4726-a830-00d8014ac468  1501009849356
# 6         6  7645-31884455-9ae0-4726-a830-00d8014ac468  1501009871308
# 7         7  7645-31884455-9ae0-4726-a830-00d8014ac468  1501009889576
# 8         8  7645-31884455-9ae0-4726-a830-00d8014ac468  1501009910004
# 9         9  7645-31884455-9ae0-4726-a830-00d8014ac468  1501009933371
# 10       10  7645-31884455-9ae0-4726-a830-00d8014ac468  1501009949791
# 11       11  7645-31884455-9ae0-4726-a830-00d8014ac468  1501009974025
# 12       12  7645-31884455-9ae0-4726-a830-00d8014ac468  1501009991587
# 13       13  7645-31884455-9ae0-4726-a830-00d8014ac468  1501010015824
# 14       14  1531-0519ed42-819e-47c9-aec3-73f1bfa8b697  1501032293921
# 15       15  1531-0519ed42-819e-47c9-aec3-73f1bfa8b697  1501032306600
# 16       16  1531-0519ed42-819e-47c9-aec3-73f1bfa8b697  1501032315179
# 17       17  1531-0519ed42-819e-47c9-aec3-73f1bfa8b697  1501032324477
# 18       18  4052-994445f3-3f93-483b-bf8b-b2b3fcee8e28  1501033341734
# 19       19  4052-994445f3-3f93-483b-bf8b-b2b3fcee8e28  1501033359914
# 20       20  4052-994445f3-3f93-483b-bf8b-b2b3fcee8e28  1501033392693
# 21       21  4052-994445f3-3f93-483b-bf8b-b2b3fcee8e28  1501033482990
# 22       22  3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096118786
# 23       23  3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096130075
# 24       24  3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096152265
# 25       25  3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096181129
# 26       26  3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096198124
# 27       27  3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096214088
# 28       28  3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096236253
# 29       29  3072-43fc98e0-fd3d-477a-81e2-7cb16e7bbb0f  1501096256219
# ...     ...                                        ...            ...
# 6397   6504  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424621076
# 6398   6505  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424628073
# 6399   6506  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424635664
# 6400   6507  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424718291
# 6401   6508  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424733955
# 6402   6509  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424741020
# 6403   6510  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424747533
# 6404   6511  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424754314
# 6405   6512  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424762806
# 6406   6513  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424770017
# 6407   6514  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424777150
# 6408   6515  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424787118
# 6409   6516  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424807586
# 6410   6517  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424817994
# 6411   6518  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424963764
# 6412   6519  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424971295
# 6413   6520  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424979630
# 6414   6521  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505424993981
# 6415   6522  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425025545
# 6416   6523  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425083334
# 6417   6524  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425097110
# 6418   6525  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425122576
# 6419   6526  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425132328
# 6420   6527  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425244273
# 6421   6528  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425251659
# 6422   6529  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425266458
# 6423   6530  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425277699
# 6424   6531  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425297972
# 6425   6532  5904-e74c7bbc-ffec-4716-8673-4480da51c799  1505425326379
# 6426   6533  3084-c6f2ba46-4b6e-41df-b3fd-133e3c75096f  1505487924118
#
#       roundNum sender       contents
# 0            1    倾听者             hi
# 1            1    演说者            接近地
# 2            1    演说者            的颜色
# 3            1    倾听者            灰色？
# 4            2    倾听者              ？
# 5            3    倾听者              ？
# 6            4    演说者           树的颜色
# 7            5    演说者             冷色
# 8            6    演说者           草的颜色
# 9            7    演说者             肉桂
# 10           8    倾听者              ？
# 11           9    倾听者              ？
# 12          10    倾听者              ？
# 13          11    倾听者              ？
# 14           0    演说者          Black
# 15           0    演说者          White
# 16           0    演说者  Ok good color
# 17           0    演说者           Reji
# 18           0    演说者              红
# 19           0    演说者              红
# 20           0    演说者              紅
# 21           0    演说者            RED
# 22           1    倾听者              ？
# 23           1    演说者          深色的血液
# 24           2    演说者             深海
# 25           3    演说者          女士 高雅
# 26           4    演说者              龙
# 27           5    演说者             土地
# 28           6    演说者             最深
# 29           7    演说者             艳丽
# ...        ...    ...            ...
# 6397        22    倾听者        嘿最近怎么样。
# 6398        23    倾听者        嘿最近怎么样。
# 6399        24    倾听者        嘿最近怎么样。
# 6400        25    倾听者        嘿最近怎么样。
# 6401        26    倾听者        嘿最近怎么样。
# 6402        27    倾听者        嘿最近怎么样。
# 6403        28    倾听者        嘿最近怎么样。
# 6404        29    倾听者        嘿最近怎么样。
# 6405        30    倾听者        嘿最近怎么样。
# 6406        31    倾听者        嘿最近怎么样。
# 6407        32    倾听者        嘿最近怎么样。
# 6408        33    倾听者        嘿最近怎么样。
# 6409        34    倾听者        嘿最近怎么样。
# 6410        35    倾听者        嘿最近怎么样。
# 6411        36    倾听者        嘿最近怎么样。
# 6412        37    倾听者        嘿最近怎么样。
# 6413        38    倾听者        嘿最近怎么样。
# 6414        39    倾听者        嘿最近怎么样。
# 6415        40    倾听者        嘿最近怎么样。
# 6416        41    倾听者        嘿最近怎么样。
# 6417        42    倾听者        嘿最近怎么样。
# 6418        43    倾听者        嘿最近怎么样。
# 6419        44    倾听者        嘿最近怎么样。
# 6420        45    倾听者        嘿最近怎么样。
# 6421        46    倾听者        嘿最近怎么样。
# 6422        47    倾听者        嘿最近怎么样。
# 6423        48    倾听者        嘿最近怎么样。
# 6424        49    倾听者        嘿最近怎么样。
# 6425        50    倾听者        嘿最近怎么样。
# 6426         0    演说者            没人啊
#
# [6427 rows x 6 columns]

# %%
~(df['l'].isin(dfc['l'])
